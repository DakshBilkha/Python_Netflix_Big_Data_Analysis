# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\DAKSH\Desktop\NETFLIX DATASET 2021.csv")

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
df.shape             #Shape(Rows,Columns)
# Out:
# (8807, 12)

# %%
df.size              #Size(Rows*Columns)
# Out:
# 105684

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=8807, step=1)

# %%
df.dtypes                  #Datatype of each columns
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.nunique()    #Category based on typology in each column
# Out:
# show_id         8807
# type               2
# title           8804
# director        4528
# cast            7692
# country          748
# date_added      1767
# release_year      74
# rating            17
# duration         220
# listed_in        514
# description     8775
# dtype: int64

# %%
df.duplicated() #To check the duplicate values in the dataset
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806    False
# Length: 8807, dtype: bool

# %%
df[df.duplicated()] #To check the duplicate values in the dataset
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
df.isnull().sum()    #To check the null values present in the dataset
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
import seaborn as sns

# %%
sns.heatmap(data=df.isnull())   #The plot shows the null values present in the dataset
# Out:
# <Axes: >

# %%
#FOR ANY MOVIE/TV SHOW, SHOW ITS CAST AND DURATION.

# %%
df[df['title'].isin(['Kota Factory'])]
# Out:
#   show_id     type         title director  \
# 4      s5  TV Show  Kota Factory      NaN
#
#                                                 cast country  \
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...   India
#
#            date_added  release_year rating   duration  \
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 4  In a city of coaching centers known to train I...

# %%
#In which year highest no. of Movies/TV Shows were released?Show a plot for the same.

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df['release_year'].value_counts().head(1)              #The release year 2018 had the highest releases.
# Out:
# release_year
# 2018    1147
# Name: count, dtype: int64

# %%
#In this case we've took the top 20 release year with highest number of releases and drew the plot for the same.
df['release_year'].value_counts().head(20).plot(kind='bar')
# Out:
# <Axes: xlabel='release_year'>

# %%
#How many TV Shows and how many Movies are there in total dataset?Show the plot for the same using Seaborn library.

# %%
df.groupby('type').type.count()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64

# %%
fig=plt.figure(figsize=(5,5))
axes=fig.add_axes([0,0,1,1])
axes.set_ylabel('Year of Release')
axes.set_xlabel('Type')
sns.countplot(x=df['type'])
plt.show()

# %%
#Show the Movies that were released in year 2000.

# %%
df[(df['type']=='Movie') & (df['release_year']==2000)]
# Out:
#      show_id   type                                              title  \
# 180     s181  Movie                 The Nutty Professor II: The Klumps
# 350     s351  Movie                                      Space Cowboys
# 359     s360  Movie                       The Original Kings of Comedy
# 566     s567  Movie                                   Charlie's Angels
# 593     s594  Movie                                           Snow Day
# 779     s780  Movie                                  Battlefield Earth
# 952     s953  Movie                               The Whole Nine Yards
# 3472   s3473  Movie                        Rugrats in Paris: The Movie
# 4545   s4546  Movie             Monty Python: Before the Flying Circus
# 4723   s4724  Movie                                               Fiza
# 4956   s4957  Movie                        Phir Bhi Dil Hai Hindustani
# 5953   s5954  Movie                             Joseph: King of Dreams
# ...

# %%
#Show the titles only of all TV Shows that were released in India only.

# %%
df[(df['type']=='TV Show')&(df['country']=='India')]['title']
# Out:
# 4                             Kota Factory
# 39                            Chhota Bheem
# 50                           Dharmakshetra
# 66           Raja Rasoi Aur Anya Kahaniyan
# 69          Stories by Rabindranath Tagore
#                        ...
# 8173                             Thackeray
# 8235                           The Calling
# 8321    The Golden Years with Javed Akhtar
# 8349                The House That Made Me
# 8775                       Yeh Meri Family
# Name: title, Length: 79, dtype: object

# %%
#Show the top 5 Directors  in the dataset.

# %%
df['director'].value_counts().head(5)        #These directors gave their highest releases
# Out:
# director
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Name: count, dtype: int64

# %%
#Categorize all ratings in the dataset.

# %%
df['rating'].nunique()
# Out:
# 17

# %%
df['rating'].unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %%
df['rating'].unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %%
#Which Movie has the highest duration amongst all the movies in the dataset?

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.duration.dtypes
# Out:
# dtype('O')

# %%
df.duration.unique()
# Out:
# array(['90 min', '2 Seasons', '1 Season', '91 min', '125 min',
#        '9 Seasons', '104 min', '127 min', '4 Seasons', '67 min', '94 min',
#        '5 Seasons', '161 min', '61 min', '166 min', '147 min', '103 min',
#        '97 min', '106 min', '111 min', '3 Seasons', '110 min', '105 min',
#        '96 min', '124 min', '116 min', '98 min', '23 min', '115 min',
#        '122 min', '99 min', '88 min', '100 min', '6 Seasons', '102 min',
#        '93 min', '95 min', '85 min', '83 min', '113 min', '13 min',
#        '182 min', '48 min', '145 min', '87 min', '92 min', '80 min',
#        '117 min', '128 min', '119 min', '143 min', '114 min', '118 min',
#        '108 min', '63 min', '121 min', '142 min', '154 min', '120 min',
#        '82 min', '109 min', '101 min', '86 min', '229 min', '76 min',
#        '89 min', '156 min', '112 min', '107 min', '129 min', '135 min',
#        '136 min', '165 min', '150 min', '133 min', '70 min', '84 min',
# ...

# %%
df[['Minutes','Units']]=df['duration'].str.split(' ',expand=True)
df      #Here we splitted the blank space in the 'duration' column and created 2 new columns accordingly.
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df[(df['type']=='Movie') & (df['Minutes'])]                         #We''ll check for the highest duration Movie
# Out:
#      show_id   type                             title  \
# 0         s1  Movie              Dick Johnson Is Dead
# 6         s7  Movie  My Little Pony: A New Generation
# 7         s8  Movie                           Sankofa
# 9        s10  Movie                      The Starling
# 12       s13  Movie                      Je Suis Karl
# ...      ...    ...                               ...
# 8801   s8802  Movie                           Zinzana
# 8802   s8803  Movie                            Zodiac
# 8804   s8805  Movie                        Zombieland
# 8805   s8806  Movie                              Zoom
# 8806   s8807  Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# 9                    Theodore Melfi
# 12              Christian Schwochow
# ...                             ...
# 8801                Majid Al Ansari
# ...

# %%
df['Minutes']=df['Minutes'].astype(float)
df.head()            #Since the 'Minutes' column was of Object dtype,so we converted the column into float dtype.
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df['Minutes'].max()                                         #Hence the highest duration was of 312 Minutes i.e 5.2Hrs
# Out:
# 312.0

# %%
df[(df['type']=='Movie') & (df['Minutes']==312.0)]          #The name of the movie is Black Mirror: Bandersnatch
# Out:
#      show_id   type                       title director  \
# 4253   s4254  Movie  Black Mirror: Bandersnatch      NaN
#
#                                                    cast        country  \
# 4253  Fionn Whitehead, Will Poulter, Craig Parkinson...  United States
#
#              date_added  release_year rating duration  \
# 4253  December 28, 2018          2018  TV-MA  312 min
#
#                                            listed_in  \
# 4253  Dramas, International Movies, Sci-Fi & Fantasy
#
#                                             description  Minutes Units
# 4253  In 1984, a young programmer begins to question...    312.0   min

# %%
#Which country got the highest number of TV Show release?

# %%
df_new=df[(df['type']=='TV Show') & (df['country'])]
df_new
# Out:
#      show_id     type                          title         director  \
# 1         s2  TV Show                  Blood & Water              NaN
# 4         s5  TV Show                   Kota Factory              NaN
# 8         s9  TV Show  The Great British Baking Show  Andy Devonshire
# 15       s16  TV Show              Dear White People              NaN
# 17       s18  TV Show                Falsa identidad              NaN
# ...      ...      ...                            ...              ...
# 8780   s8781  TV Show                   Yo-Kai Watch              NaN
# 8795   s8796  TV Show                Yu-Gi-Oh! Arc-V              NaN
# 8796   s8797  TV Show                     Yunus Emre              NaN
# 8797   s8798  TV Show                      Zak Storm              NaN
# 8800   s8801  TV Show             Zindagi Gulzar Hai              NaN
#
#                                                    cast  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# ...

# %%
df_new.country.value_counts()
# Out:
# country
# United States                                    760
# United Kingdom                                   213
# Japan                                            169
# South Korea                                      158
# India                                             79
#                                                 ...
# Belarus                                            1
# United Kingdom, Australia                          1
# France, Australia, Germany                         1
# Australia, New Zealand, United States              1
# United States, France, South Korea, Indonesia      1
# Name: count, Length: 196, dtype: int64

# %%
df_new.country.value_counts().head(1)                       # United States had the highest releases of TV Shows.
# Out:
# country
# United States    760
# Name: count, dtype: int64

# %%
#Show the titles of TV Shows that were rated 'R'.

# %%
df[(df['rating']=='R') & (df['type']=='TV Show')]
# Out:
#      show_id     type                                title           director  \
# 3893   s3894  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
# 7593   s7594  TV Show                                Nobel                NaN
#
#                                                    cast country  \
# 3893  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN
# 7593  Aksel Hennie, Tuva Novotny, Anders Danielsen L...  Norway
#
#              date_added  release_year rating  duration  \
# 3893     April 25, 2019          2015      R  1 Season
# 7593  December 10, 2016          2016      R  1 Season
#
#                                             listed_in  \
# 3893                                         TV Shows
# 7593  International TV Shows, TV Dramas, TV Thrillers
#
#                                             description  Minutes   Units
# 3893  Trapped at a stagecoach stop as a storm rages ...      1.0  Season
# ...

# %%
#In how many Movies 'Ben Affleck' was cast?

# %%
df_2=df.dropna()   #It dropped all the null values in the dataset.

# %%
df_2[df_2['cast'].str.contains('Ben Affleck')]
# Out:
#      show_id   type                           title  \
# 608     s609  Movie            The Sum of All Fears
# 947     s948  Movie                   State of Play
# 2897   s2898  Movie        The Last Thing He Wanted
# 4024   s4025  Movie                 Triple Frontier
# 5953   s5954  Movie          Joseph: King of Dreams
# 6450   s6451  Movie                     Chasing Amy
# 7121   s7122  Movie  Jay and Silent Bob Strike Back
# 8251   s8252  Movie                 The Company Men
#
#                            director  \
# 608             Phil Alden Robinson
# 947                 Kevin Macdonald
# 2897                       Dee Rees
# 4024                   J.C. Chandor
# 5953  Rob LaDuca, Robert C. Ramirez
# 6450                    Kevin Smith
# 7121                    Kevin Smith
# 8251                     John Wells
#
#                                                    cast  \
# 608   Ben Affleck, Morgan Freeman, Bridget Moynahan,...
# ...

# %%
                                               #END OF THE PROJECT#
